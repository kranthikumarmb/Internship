# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars.

# %%
import selenium
import pandas as pd
# we are importing warning functions to avoid warnoings pop ups
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver 
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://www.amazon.in')

# %%
# we are taken k as variable for the user input 
k=input('enter a product : ')
de=d.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')
# we made k as send keys as user product input
de.send_keys(k)
se=d.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]')
se.click()
brand=[]
price=[]
Producturl=[]
# Out:
# enter a product : latest phones

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your
# search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
b=d.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in b:
    bd=i.text
    brand.append(bd)
p=d.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in p:
    pr=i.text
    price.append(pr)
l=d.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in l:
    k=i.get_attribute('href')
    Producturl.append(k)

# %%
#length of the products before extracting from the next page
len(price),len(brand),len(Producturl)
# Out:
# (22, 22, 22)

# %%
st=0
end=3

for page in(st,end):
    b=d.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in b:
        bd=i.text
        brand.append(bd)
    p=d.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in p:
        pr=i.text
        price.append(pr)
    l=d.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in l:
        k=i.get_attribute('href')
        Producturl.append(k)
    next_page=d.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]') 
    next_page.click()
    time.sleep(3)

# %%
df=pd.DataFrame({'brand':brand,'price':price,'Product URL':Producturl})
df
# Out:
#                                                 brand   price  \
# 0   Samsung Galaxy M04 Light Green, 4GB RAM, 128GB...  10,499
# 1   Lava X3(Charcoal Black, 3GB RAM, 32GB Storage)...   6,999
# 2   Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...   8,499
# 3   Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...   7,499
# 4   Redmi 10A (Charcoal Black, 4GB RAM, 64GB Stora...   8,299
# ..                                                ...     ...
# 61  MI REDMI 9i Sport (Carbon Black, 64 GB) (4 GB ...   7,700
# 62  Nokia G21 Android Smartphone, Dual SIM, 3-Day ...  13,499
# 63  Redmi Note 11 Pro + 5G (Stealth Black, 8GB RAM...  22,999
# 64  IKALL K435 Smartphone (4GB, 64GB) (Fast Chargi...   6,799
# 65  Vivo Y16 (Drizzling Gold, 3GB RAM, 32GB Storag...   9,999
#
#                                           Product URL
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2   https://www.amazon.in/Redmi-Activ-Carbon-Black...
# ...

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
import selenium
import pandas as pd
# we are importing warning functions to avoid warnoings pop ups
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver 
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://images.google.com')

# %%
search_bar=d.find_element(By.XPATH,'//input[@class="gLFyf"]')
search_bar.send_keys('dogs')
search_button=d.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()

# %%
import requests
for _ in range(20):
    d.execute_script("window.scrollBy(0,1000)")


images=d.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
src=[]
for i in images[0:10]:
    source=i.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            src.append(source)

for i in range(len(src)):
    if i > 10:
        breakBy.XPATH,
    print('downloading {0} of {1}  images'.format(i,10))
    response=requests.get(src[i])
    file=open(r"c:\Users\HP\Admin\Desktop"+str(i)+"jpg","wb")
    file.write(response.content)

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://www.flipkart.com')

# %%
search_bar=d.find_element(By.XPATH,'//input[@class="_3704LK"]')
search_bar.send_keys('smartphones')
search_button=d.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_button.click()

# %%
Brand_Name=[]
Smartphone_name=[]
Colour=[]
RAM=[]
Storage_ROM=[]
Primary_Camera=[]
Secondary_Camera=[]
Display_Size=[]
Battery_Capacity=[]
Price=[]
Product_URL=[]
b=d.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in b:
    br=i.text.split(' ')[0:1]
    Brand_Name.append(br)
s=d.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in s:
    bp=i.text.split(' ')[1:2]
    Smartphone_name.append(bp)
c=d.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in c:
    co=i.text.split(' ')[3:8]
    Colour.append(co)
r=d.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in r:
    ra=i.text
    RAM.append(ra)
list1=[]
for i in range(0,144,6):
    list1.append(RAM[i])

# %%
list2=[]#display size
cam=d.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in cam:
    ca=i.text
    Primary_Camera.append(ca)
for i in range(1,144,6):
    list2.append(Primary_Camera[i])

# %%
list3=[]# camera
cam=d.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in range(2,144,6):
    list3.append(Primary_Camera[i])

# %%
list4=[]
bat=d.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in bat:
    ba=i.text
    Battery_Capacity.append(ba)
for i in range(3,144,6):
    list4.append(Battery_Capacity[i])

# %%
p=d.find_elements(By.XPATH,'//div[@class="_3tbKJL"]')
for i in p:
    pr=i.text
    Price.append(pr)

# %%
link=d.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in link:
    pl=i.get_attribute('href')
    Product_URL.append(pl)

# %%
df=pd.DataFrame({'Brand name':Brand_Name,'Smartphone_Model_Name':Smartphone_name,'RAM  | ROM':list1,' mobile colour':Colour,'Display size':list2,'Primary camera  | secondary camera':list3,'Battery capacity':list4,'Mobile Price':Price,'Produt link':Product_URL})
df
# Out:
#     Brand name Smartphone_Model_Name  \
# 0      [REDMI]                  [9i]
# 1       [POCO]                 [C31]
# 2      [REDMI]                  [9i]
# 3       [POCO]                 [C31]
# 4      [REDMI]                  [10]
# 5   [MOTOROLA]                 [e40]
# 6   [MOTOROLA]                 [e40]
# 7     [realme]                  [9i]
# 8     [realme]                  [9i]
# 9     [realme]                  [9i]
# 10    [realme]                  [9i]
# 11     [REDMI]                  [9i]
# 12     [REDMI]                  [10]
# 13  [MOTOROLA]                 [G32]
# 14  [MOTOROLA]                 [g52]
# 15    [realme]                   [9]
# 16    [realme]                   [9]
# 17      [POCO]                 [C31]
# 18  [MOTOROLA]                 [g52]
# 19    [realme]                  [9i]
# 20     [REDMI]                  [10]
# 21      [POCO]                  [M4]
# 22  [MOTOROLA]                 [G32]
# 23     [APPLE]              [iPhone]
#
# ...

# %%
df.to_csv('smartphones.csv')

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
import selenium
import pandas as pd
# we are importing warning functions to avoid warnoings pop ups
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver 
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://www.googlemaps.com')

# %%
search_bar=d.find_element(By.XPATH,'//input[@class="searchboxinput xiQnY"]')
search_bar.send_keys('new york')
search_button=d.find_element(By.XPATH,'//button[@class="mL3xi"]')
search_button.click()

# %%
url=d.current_url
print('current url :',url)# url shows us the current location
lat_long =url.split('/')[6]# we are splitting the url into collan to separate the link
latitude_longitude=lat_long.split('@')[1]
print('latitude_longitude :',latitude_longitude)
# Out:
# current url : https://www.google.com/maps/place/New+York,+NY,+USA/@40.6971494,-74.2598685,10z/data=!3m1!4b1!4m5!3m4!1s0x89c24fa5d33f083b:0xc80b8f06e177fe62!8m2!3d40.7127753!4d-74.0059728
# latitude_longitude : 40.6971494,-74.2598685,10z

# %% [markdown]
# # 6.Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in.

# %% [markdown]
# in doubt clearring seesion they said to leave this question for choice

# %% [markdown]
# # 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
import selenium
import pandas as pd
# we are importing warning functions to avoid warnoings pop ups
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver 
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://www.digit.in')

# %%
top=d.find_element(By.XPATH,'/html/body/div[1]/div/div[4]/ul/li[4]')
top.click()

# %%
laptops=d.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[5]/div[1]/div/button[2]')
laptops.click()

# %%
gaming_laptops=d.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[5]/div[3]/div[3]/a/div[2]')
gaming_laptops.click()

# %%
windows=[]

lap=d.find_elements(By.XPATH,'//div[@class="value"]')
for i in lap:
    la=i.text
    windows.append(la)
list1=[]   #windows model 
for k in range(0,44,4):
    list1.append(windows[k])
list2= []#display
for l in range(1,44,4):
    list2.append(windows[l])
list3= []   # processor model of the systen
for  m in range(2,44,4):
    list3.append(windows[m])
list4=[]# momory of the system
for v in range(3,44,4):
    list4.append(windows[v])

# %%
df=pd.DataFrame({'windows version':list1,' display size':list2,'processor of the lapotop':list3,'ROM and SSD':list4})
df.to_csv('laptop .csv')
df
# Out:
#        windows version                 display size  \
# 0   Windows 11 Home OS  17.3" (3840 x 2160) Display
# 1   Windows 11 Home OS  17.3" (1920 x 1080) Display
# 2        Windows 11 OS    16" (2560 x 1600) Display
# 3      Windows 11 Home          17.3" (1920 X 1080)
# 4   Windows 11 Home OS  16.1" (2560 x 1440) Display
# 5   Windows 11 Home OS  15.6" (2560 x 1440) Display
# 6   Windows 11 Home OS  15.6" (1920 x 1080) Display
# 7   Windows 11 Home OS  16.1" (2560 x 1440) Display
# 8   Windows 11 Home OS    16" (2560 x 1600) Display
# 9   Windows 11 Home OS  15.6" (1920 x 1080) Display
# 10  Windows 11 Home OS         15.6 MP | NA Display
#
#                              processor of the lapotop  \
# 0       12th Gen Intel Core i9-12900HX | NA Processor
# 1     12th Gen Intel Core i9-12900H | 5 GHz Processor
# 2   12th Gen Intel Core i7-12700H | 3.5 GHz Processor
# 3                         AMD Ryzen 7-6800H | 4.7 GHz
# 4   12th Gen Intel Core i7-12700H | 4.7 GHz Processor
# ...

# %% [markdown]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
import selenium
import pandas as pd
# we are importing warning functions to avoid warnoings pop ups
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver 
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://www.forbes.com')

# %%
list=d.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div/div/div[1]')
list.click()

india=d.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div/div/div[2]/ul/li[1]/div[2]/div[3]/ul/li[5]/a')
india.click()

# %%
names=[]
worth=[]
industry=[]
rank=[]
richest=d.find_elements(By.XPATH,'//div[@class="personName second table-cell  name"]')
for i in richest[0:50]:
    hj=i.text
    names.append(hj)
wor=d.find_elements(By.XPATH,'//div[@class="finalWorth  table-cell  net worth "]')
for k in wor[0:50]:
    kl=k.text
    worth.append(kl)
ind=d.find_elements(By.XPATH,'//div[@class="category  table-cell  industry"]')
for ids in ind[0:50]:
    iny=ids.text
    industry.append(iny)
ra=d.find_elements(By.XPATH,'//div[@class="rank first table-cell  rank"]')
for ran in ra[0:50]:
    r=ran.text
    rank.append(r)

# %%
df1=pd.DataFrame({'Rank ':rank,'Name':names,'networth':worth,'Industry':industry})
df1.to_csv('forbes.csv')
df1
# Out:
#    Rank                                                Name networth  \
# 0     1.                              Gautam Adani & family   $150 B
# 1     2.                                      Mukesh Ambani    $88 B
# 2     3.                        Radhakishan Damani & family  $27.6 B
# 3     4.                                   Cyrus Poonawalla  $21.5 B
# 4     5.                                         Shiv Nadar  $21.4 B
# 5     6.                            Savitri Jindal & family  $16.4 B
# 6     7.                            Dilip Shanghvi & family  $15.5 B
# 7     8.                                   Hinduja brothers  $15.2 B
# 8     9.                                        Kumar Birla    $15 B
# 9    10.                                       Bajaj Family  $14.6 B
# 10   11.                              Sunil Mittal & family  $14.5 B
# 11   12.                                         Uday Kotak  $14.3 B
# 12   13.                            Shapoor Mistry & family  $14.2 B
# ...

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.

# %%
import selenium
import pandas as pd
# we are importing warning functions to avoid warnoings pop ups
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver 
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://www.youtube.com')

# %%
search_bar=d.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search_bar.send_keys('Veera Soora')
search_button=d.find_element(By.XPATH,'//button[@id="search-icon-legacy"]')
search_button.click()

# %%
song=d.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div[2]/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/div/div[1]/div/h3/a/yt-formatted-string')
song.click()

# %%
comments=[]
postedcomments=[]
comment=d.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
for i in comment[0:500]:
    ca=i.text
    comments.append(ca)
comm=d.find_elements(By.XPATH,'//span[@class="style-scope yt-formatted-string"]') 
for k in comm[0:500]:
    pos=k.text
    postedcomments.append(pos)

# %%
df=pd.DataFrame({'comment posted time':comments,'commented':postedcomments})
df
# Out:
#     comment posted time                                          commented
# 0
# 1
# 2
# 3
# 4
# ..                  ...                                                ...
# 495         1 month ago                                  U1+Selva+Dhanush
# 496         1 month ago                       நானே வருவேன் கதிர் intervel
# 497         1 month ago                                         Vera level
# 498         1 month ago  കേട്ടു കൊണ്ടിരിക്കുമ്പോൾ കേട്ടിരിക്കുന്ന വന്  ...
# 499         1 month ago                                                 ..
#
# [500 rows x 2 columns]

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description.

# %%
import selenium
import pandas as pd
# we are importing warning functions to avoid warnoings pop ups
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver 
from selenium.webdriver.common.by import By
import time
d=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
# to max the window size we are using maximize_window()
d.maximize_window()
d.get('https://www.hostelworld.com/')

# %%
search_bar=d.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')
search_bar.send_keys('London,england')

# %%
lg=d.find_element(By.XPATH,'//button[@class="button primary large"]')
lg.click()

# %%
p=d.find_elements(By.XPATH,'//div[@class="reviews"]')
for i in p:
    price=i.text
